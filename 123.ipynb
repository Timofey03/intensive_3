# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn

import pandas as pd 
import numpy as np

# %%
db = pd.read_excel("test.xlsx")

# %%
db
# Out:
#            dt  Цена на арматуру
# 0  2022-09-05             46000
# 1  2022-09-12             46000
# 2  2022-09-19             46000
# 3  2022-09-26             45500
# 4  2022-10-03             45500
# 5  2022-10-10             45000
# 6  2022-10-17             44000
# 7  2022-10-24             43000
# 8  2022-10-31             42000
# 9  2022-11-07             41500
# 10 2022-11-14             41000
# 11 2022-11-21             40000
# 12 2022-11-28             40000
# 13 2022-12-05             40500
# 14 2022-12-12             41700
# 15 2022-12-19             41700
# 16 2022-12-26             42500
# 17 2023-01-02             42700
# 18 2023-01-09             42700
# 19 2023-01-16             42700
# 20 2023-01-23             42800
# 21 2023-01-30             42800
# 22 2023-02-06             44500
# 23 2023-02-13             44500
# 24 2023-02-20             46000
# 25 2023-02-27             49200
# 26 2023-03-06             53700
# 27 2023-03-13             55500

# %%
db.describe()
# Out:
#                         dt  Цена на арматуру
# count                   28         28.000000
# mean   2022-12-08 12:00:00      44250.000000
# min    2022-09-05 00:00:00      40000.000000
# 25%    2022-10-22 06:00:00      41925.000000
# 50%    2022-12-08 12:00:00      42900.000000
# 75%    2023-01-24 18:00:00      45625.000000
# max    2023-03-13 00:00:00      55500.000000
# std                    NaN       3645.951585

# %%
import matplotlib.pyplot as plt

# %%
db['dt'] = pd.to_datetime(db['dt']) 

# setting index 
db.set_index('dt', inplace=True) 

# plotting figure 
db.plot.line()
# Out:
# <Axes: xlabel='dt'>

# %%
# Out:
#   Cell In[12], line 5
#     time_series, lambda = stats.boxcox(time_series)
#                         ^
# SyntaxError: invalid syntax
